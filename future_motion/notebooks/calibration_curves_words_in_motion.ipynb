# %%
import torch
import numpy as np

from future_motion.utils.plot_calibration_curves import plot_calibration_curve

# %%
plot_calibration_curve(file_path="calibration_mean_plain_pca_av2f.pt", title="Plain PCA AV2F")
